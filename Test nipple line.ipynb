# %%
from mammo_dataset import INbreastDataset
import pandas as pd
from glob import glob
import os.path as osp
import xml.etree.ElementTree as ET
import cv2

# %%
inbreast_dir = '/Users/lpires/Developer/dl/INbreast'
mammo_kp_dir = '/Users/lpires/Developer/dl/mammo_kp'

# %%
# ds = INbreastDataset(inbreast_dir, None)
# ds.read_dicoms()
# ds.read_cases()
# cases_df = ds.cases_df.reset_index()
# cases_df.to_csv('cases_df.csv', index=False)

# %%
cases_df = pd.read_csv('cases_df.csv')
kp_df = pd.DataFrame(
    [[int(osp.splitext(osp.basename(fn))[0]), fn] for fn in glob(osp.join(mammo_kp_dir, 'annotations', '*.xml'))],
    columns=['case_id', 'fn']
)

# %%
join_df = cases_df.join(kp_df.set_index('case_id'), how='inner', on='case_id')
join_df['helper'] = join_df.apply(lambda r: '%s%s' % (r['view'], r['laterality']), axis =1)

# %%
assert len(join_df) == len(kp_df)

# %%
#
# check duplicates
#

# %%
pivot = pd.pivot_table(join_df, index=['patient_id'], columns=['helper'], values=['fn'], aggfunc='count')['fn']

# %%
pivot = pivot[~pivot['MLOL'].isnull() & ~pivot['MLOR'].isnull()]

# %%
pivot_ones = pivot[(pivot['MLOL'] == 1.0) & (pivot['MLOR'] == 1.0)]
pivot_others = pivot[(pivot['MLOL'] != 1.0) | (pivot['MLOR'] != 1.0)]

# %%
assert len(pivot) == len(pivot_ones)
assert len(pivot_others) == 0

# %%
#
# mount imagens and keypoints matching
#

# %%
filtered_df = join_df[join_df['patient_id'].isin(pivot_ones.index)][['case_id', 'laterality', 'patient_id', 'fn']]

# %%
assert len(filtered_df) == 2 * len(pivot_ones)

# %%
data = {}
for _, r in filtered_df.iterrows():
    patient_id = r['patient_id']
    laterality = r['laterality']
    fn = r['fn']
    # parse lines
    tree = ET.parse(fn)
    root = tree.getroot()
    line_e = root.find('./object/line')
    line = [int(e.text) for e in list(line_e)]
    # build dict
    case_id = int(osp.splitext(osp.basename(fn))[0])
    if patient_id in data:
        x = data[patient_id]
    else:
        x = [None, None, None, None]
        data[patient_id] = x
    if laterality == 'L':
        x[0] = line
        x[2] = case_id
    elif laterality == 'R':
        x[1] = line
        x[3] = case_id
mount_df = pd.DataFrame.from_dict(data, orient='index', columns=['Lline', 'Rline', 'Lcase_id', 'Rcase_id'])
mount_df.sort_index(inplace=True)
mount_df.reset_index().to_csv('mount_df.csv', index=False)

# %%
# if want to check one case for debugging
# mount_df = mount_df[mount_df['Lcase_id'] == 22678694]

# %%
#
# draw samples
#

# %%
for patient_id, r in mount_df.iterrows():
    l_line = r['Lline']
    r_line = r['Rline']
    l_case_id = r['Lcase_id']
    r_case_id = r['Rcase_id']
    
    l_img = cv2.imread(osp.join(mammo_kp_dir, '%d.png' % l_case_id))
    r_img = cv2.imread(osp.join(mammo_kp_dir, '%d.png' % r_case_id))

    l_mask = cv2.imread(osp.join(mammo_kp_dir, 'annotations', '%d_pixels1.png' % l_case_id))
    r_mask = cv2.imread(osp.join(mammo_kp_dir, 'annotations', '%d_pixels1.png' % r_case_id))
    l_mask = cv2.bitwise_and(l_mask, (0, 255, 0), mask=cv2.cvtColor(l_mask, cv2.COLOR_BGR2GRAY))
    r_mask = cv2.bitwise_and(r_mask, (0, 255, 0), mask=cv2.cvtColor(r_mask, cv2.COLOR_BGR2GRAY))
    
    l_final = cv2.addWeighted(l_img, 1.0, l_mask, 0.05, 0)
    r_final = cv2.addWeighted(r_img, 1.0, r_mask, 0.05, 0)
    
    l_final = cv2.line(l_final, (l_line[0], l_line[1]), (l_line[2], l_line[3]), color=(0, 0, 255), thickness=5)
    r_final = cv2.line(r_final, (r_line[0], r_line[1]), (r_line[2], r_line[3]), color=(0, 0, 255), thickness=5)

    img_final = cv2.hconcat([r_final, l_final])
    
    cv2.imwrite(osp.join(mammo_kp_dir, 'qa', '%s.png' % patient_id), img_final)

# %%
mount_df[['Rcase_id', 'Lcase_id']].to_clipboard()

# %%
mount_df
# Out:
#                                  Lline                 Rline  Lcase_id  \
# 024ee3569b2605dc   [371, 334, 24, 173]  [273, 355, 612, 174]  20588072
# 036aff49b8ac84f0   [431, 423, 81, 241]  [395, 370, 764, 203]  20588680
# 069212ec65a94339   [281, 316, 49, 255]  [414, 305, 596, 257]  50994733
# 0b7396cdccacca82    [343, 383, 8, 193]  [466, 381, 754, 200]  22670878
# 1e10aef17c9fe149   [425, 423, 49, 183]  [400, 414, 772, 181]  24055274
# 1f139436acfc5467   [336, 454, 34, 230]  [477, 473, 761, 229]  50998413
# 21e6cc12630e5e9f   [244, 314, 32, 226]  [369, 304, 630, 221]  53581860
# 2a5b932da4ce5ca1   [344, 304, 85, 174]  [346, 327, 566, 181]  22580576
# 2dec4948fbe6336d   [394, 336, 45, 165]  [278, 326, 630, 154]  22614568
# 2f1104b3cda7f145    [255, 321, 3, 218]  [425, 252, 663, 125]  24054997
# 301f1776aebbf5d2   [338, 303, 58, 198]  [293, 328, 601, 192]  22579916
# 349323117bf0fd93   [240, 336, 68, 219]  [428, 329, 597, 206]  30011553
# 3f0db31711fc9795  [308, 388, 150, 225]  [375, 358, 606, 209]  53582395
# 40e22f2e3215b954   [410, 527, 26, 316]  [416, 533, 741, 315]  53580611
# 45c7f44839fd9e68    [364, 433, 3, 220]  [437, 308, 780, 224]  22613848
# 465aa5ec1b59efc6    [219, 353, 7, 171]  [290, 396, 616, 167]  53582656
# 4c341dad22471922   [301, 317, 44, 266]  [370, 340, 639, 263]  53580979
# 4f20c1285d8f0b1f   [441, 434, 86, 240]  [468, 421, 778, 226]  30318067
# 51bec6477a7898b9  [355, 475, 102, 237]  [491, 484, 748, 219]  53580804
# f23fa352e7de3dc7   [271, 312, 24, 165]  [388, 342, 613, 193]  22613996
# f34ee0ab6591b792  [417, 445, 105, 257]  [390, 449, 726, 253]  50998177
# f4b2d377f43ba0bd   [498, 310, 15, 279]  [306, 349, 810, 216]  20587690
# f8bfddc28e8045c0   [208, 312, 46, 180]  [459, 315, 636, 179]  26933859
# fbb55bf7fff48540   [427, 423, 60, 239]  [391, 425, 738, 221]  27829215
# fd746d25eb40b3dc   [223, 354, 36, 228]  [392, 316, 595, 192]  20587226
# fdf4a1516f88b280   [586, 440, 70, 290]  [362, 495, 799, 298]  50996800
# fe7d005dcbbfb46d    [317, 496, 7, 272]  [412, 539, 734, 312]  22580732
#
#                   Rcase_id
# 024ee3569b2605dc  20588046
# 036aff49b8ac84f0  20588654
# 069212ec65a94339  50994760
# 0b7396cdccacca82  22670855
# 1e10aef17c9fe149  24055328
# 1f139436acfc5467  50998440
# 21e6cc12630e5e9f  53581887
# 2a5b932da4ce5ca1  22580548
# 2dec4948fbe6336d  22614545
# 2f1104b3cda7f145  24055024
# 301f1776aebbf5d2  22579893
# 349323117bf0fd93  30011530
# 3f0db31711fc9795  53582422
# 40e22f2e3215b954  53580638
# 45c7f44839fd9e68  22613822
# 465aa5ec1b59efc6  53582710
# 4c341dad22471922  53581006
# 4f20c1285d8f0b1f  30011850
# 51bec6477a7898b9  53580831
# 5291e1aee2bbf5df  24065707
# 5530d5782fc89dd7  22580244
# 5eae9beae14d26fd  22580393
# 5fb370d4c1c71974  53587717
# 606e9b184978a350  24055176
# 60995d51033e24b8  22678495
# 61b13c59bcba149e  22678670
# 6200187f3f1ccc18  22580068
# 64a22c47765f0c5c  22678833
# 66adfbb4f19c76d2  50998086
# 67cc8c9939d74a9a  50997624
# ...                    ...
# b231a8ba4dd4214f  53581406
# b9a4da5f2dae63a9  22679008
# bbd6a3a35438c11b  22579730
# bf1a6aaadb05e3df  20588510
# c01f83a1eb283270  24065860
# c4b995eddb3c510c  24065270
# cb65e8dac169f596  50999121
# cbb6c98a81e69eeb  50997769
# cc9e66c5b31baab8  50994354
# cd12bc20b3d27d0b  50998607
# ce5e5e18a261cd29  50996972
# d065adcb9905b973  22614405
# d2befe622e188943  53587454
# d713ef5849f98b6c  22427728
# d8205a09c8173f44  24065557
# dcafa6ba6374ec07  22613676
# de5e8d61e501a71b  50993814
# e15a16f87b4f9782  22670673
# e1f51192f7bf3f5f  22670147
# e5f3f68b9ce31228  53586751
# e634830794f5c1bd  20587346
# f0f1a133837b5137  24055752
# f23fa352e7de3dc7  22613970
# f34ee0ab6591b792  50998204
# f4b2d377f43ba0bd  20587664
# f8bfddc28e8045c0  26933830
# fbb55bf7fff48540  27829188
# fd746d25eb40b3dc  20587200
# fdf4a1516f88b280  50996827
# fe7d005dcbbfb46d  22580706
#
# [79 rows x 4 columns]
